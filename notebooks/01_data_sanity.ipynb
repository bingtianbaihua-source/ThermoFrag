# %% [markdown]
# # 01 Data sanity
#
# Open every preprocessed dataset, print shapes, plot histograms of molecule sizes, verify checksum manifests. This is the exit criterion for Phase 0 (see docs/MILESTONES.md).

# %%
from pathlib import Path
import json
import numpy as np
import matplotlib.pyplot as plt

ROOT = Path('..').resolve()
PROCESSED = ROOT / 'data' / 'processed'
print('processed root:', PROCESSED)
for p in PROCESSED.glob('*'):
    print(' -', p.name)

# %%
# TODO: open each .npz / .lmdb / .parquet and plot heavy-atom-count histograms
